# %% [markdown]
# tensor broadcasting:

# %%
import torch

tensor1 = torch.tensor([[1, 2, 3, 4]])
tensor2 = torch.tensor([1, 2, 3, 4]).unsqueeze(1)  # (4,1)

print(tensor1.shape)
print(tensor2.shape)

tensor3 = tensor1 + tensor2
print(tensor3)
# Out:
# torch.Size([1, 4])
# torch.Size([4, 1])
# tensor([[2, 3, 4, 5],
#         [3, 4, 5, 6],
#         [4, 5, 6, 7],
#         [5, 6, 7, 8]])
